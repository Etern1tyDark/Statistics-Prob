# %% [markdown]
# Module 1.1 Practice
#
# Nathan Kho Pancras
#
# 5027231002, Stat-Prob (B)

# %%
# Latihan 2
# Module 1.1

import matplotlib.pyplot as plt

# Import library Counter untuk menghitung modus
from collections import Counter

# Inisialisasi dataset
data = [95, 35, 50, 65, 70, 85, 25, 100, 80, 90, 45, 40, 35, 20, 75, 50, 40, 60, 80, 75]
print(f"Data: {data}")

# Mengurutkan data dari terkecil hingga terbesar
sorted_data = sorted(data)
print(f"\nData berurut: {sorted_data}")

# Jumlah total data dalam dataset 
n = len(sorted_data)
print(f"\nJumlah total data: {n}")

# Jumlah nilai dalam dataset 
jumlah_nilai = sum(data)
print(f"\nJumlah semua nilai: {jumlah_nilai}")

# Jumlah total data dalam dataset 
jumlah_total_data = len(data)
print(f"\nJumlah total data: {jumlah_total_data}")

# Jumlah semua nilai dalam dataset 
mean_value = jumlah_nilai / jumlah_total_data
print(f"\nMean: {mean_value}")

index_tengah = n//2 # double slash // is used for floor division

# Jika jumlah data genap, median adalah rata-rata dari dua nilai tengah 
if n % 2 == 0:
    print(f"Jumlah total data Genap")
    median1 = sorted_data[index_tengah]
    median2 = sorted_data[index_tengah - 1]
    print(f"Nilai tengah: {median1} {median2}")
    median_value = (median1 + median2) / 2
    
# Jika jumlah data ganjil, median adalah nilai tengah
else:
    print(f"\nJumlah total data Ganjil")
    median_value = sorted_data[index_tengah]
    print(f"Nilai tengah: {median_value}")

print(f"\nMedian: {median_value}")

counter = Counter(data)
mode_data = dict(counter) # ubah ke tipe data dictionary
max_counter = max(list(counter.values())) # mencari data yang memiliki counter paling banyak
print(f"\nMax Counter: {max_counter}")

mode_value = []
for k, v in mode_data.items():
    if v == max(list(counter.values())):
        mode_value.append(k)
    
print(f"\nMode: {mode_value}")

# Create a histogram
plt.hist(data, bins=30, edgecolor='black', alpha=0.5, color='blue')

# Add a vertical line at the mean
plt.axvline(x=mean_value, color='red', linestyle='dashed', linewidth=1.5, label=f'Mean = {mean_value:.2f}')
plt.axvline(x=median_value, color='green', linestyle='dashed', linewidth=1.5, label=f'Median = {median_value:.2f}')

j = len(mode_value)
for i in range (0, j):
    plt.axvline(x=mode_value[i], color='black', linestyle='dashed', linewidth=1.25)

# Add labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Mean, Median, Modus')

# Add legend
plt.legend()

# Show the plot
plt.show()
# Out:
# Data: [95, 35, 50, 65, 70, 85, 25, 100, 80, 90, 45, 40, 35, 20, 75, 50, 40, 60, 80, 75]
#
# Data berurut: [20, 25, 35, 35, 40, 40, 45, 50, 50, 60, 65, 70, 75, 75, 80, 80, 85, 90, 95, 100]
#
# Jumlah total data: 20
#
# Jumlah semua nilai: 1215
#
# Jumlah total data: 20
#
# Mean: 60.75
# Jumlah total data Genap
# Nilai tengah: 65 60
#
# Median: 62.5
#
# Max Counter: 2
#
# Mode: [35, 50, 80, 40, 75]

# %% [markdown]
# Dalam Practice 1.1 Latihan 1, diketahui tinggi badan siswa kelas A adalah 100,5 ; 99,7 ; 101 ; 101,3 ; 99,9 ; 98,9 ; 165 ; 102,2 ; 98,7 ; 102,9 ; dan 100. Menggunakan Mean, Median, dan Modus, yang paling bagus adalah Median, karena dalam data ada satu data yang berbeda jauh dari yang lain, sehingga memengaruhi Mean, dan jumlah Modus (hitam) terlalu banyak karena banyak data yang sama dalam jumlah frekuensi.

# %%
# Latihan 2
# Module 1.1

import matplotlib.pyplot as plt

# Import library Counter untuk menghitung modus
from collections import Counter

# Inisialisasi dataset
data = [95, 35, 50, 65, 70, 85, 25, 100, 80, 90, 45, 40, 35, 20, 75, 50, 40, 60, 80, 75]
print(f"Data: {data}")

# Mengurutkan data dari terkecil hingga terbesar
sorted_data = sorted(data)
print(f"\nData berurut: {sorted_data}")

# Jumlah total data dalam dataset 
n = len(sorted_data)
print(f"\nJumlah total data: {n}")

# Jumlah nilai dalam dataset 
jumlah_nilai = sum(data)
print(f"\nJumlah semua nilai: {jumlah_nilai}")

# Jumlah total data dalam dataset 
jumlah_total_data = len(data)
print(f"\nJumlah total data: {jumlah_total_data}")

# Jumlah semua nilai dalam dataset 
mean_value = jumlah_nilai / jumlah_total_data
print(f"\nMean: {mean_value}")

index_tengah = n//2 # double slash // is used for floor division

# Jika jumlah data genap, median adalah rata-rata dari dua nilai tengah 
if n % 2 == 0:
    print(f"Jumlah total data Genap")
    median1 = sorted_data[index_tengah]
    median2 = sorted_data[index_tengah - 1]
    print(f"Nilai tengah: {median1} {median2}")
    median_value = (median1 + median2) / 2
    
# Jika jumlah data ganjil, median adalah nilai tengah
else:
    print(f"\nJumlah total data Ganjil")
    median_value = sorted_data[index_tengah]
    print(f"Nilai tengah: {median_value}")

print(f"\nMedian: {median_value}")

counter = Counter(data)
mode_data = dict(counter) # ubah ke tipe data dictionary
max_counter = max(list(counter.values())) # mencari data yang memiliki counter paling banyak
print(f"\nMax Counter: {max_counter}")

mode_value = []
for k, v in mode_data.items():
    if v == max(list(counter.values())):
        mode_value.append(k)
    
print(f"\nMode: {mode_value}")

# Create a histogram
plt.hist(data, bins=30, edgecolor='black', alpha=0.5, color='blue')

# Add a vertical line at the mean
plt.axvline(x=mean_value, color='red', linestyle='dashed', linewidth=1.5, label=f'Mean = {mean_value:.2f}')
plt.axvline(x=median_value, color='green', linestyle='dashed', linewidth=1.5, label=f'Median = {median_value:.2f}')

j = len(mode_value)
for i in range (0, j):
    plt.axvline(x=mode_value[i], color='black', linestyle='dashed', linewidth=1.25)

# Add labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Mean, Median, Modus')

# Add legend
plt.legend()

# Show the plot
plt.show()
# Out:
# Data: [95, 35, 50, 65, 70, 85, 25, 100, 80, 90, 45, 40, 35, 20, 75, 50, 40, 60, 80, 75]
#
# Data berurut: [20, 25, 35, 35, 40, 40, 45, 50, 50, 60, 65, 70, 75, 75, 80, 80, 85, 90, 95, 100]
#
# Jumlah total data: 20
#
# Jumlah semua nilai: 1215
#
# Jumlah total data: 20
#
# Mean: 60.75
# Jumlah total data Genap
# Nilai tengah: 65 60
#
# Median: 62.5
#
# Max Counter: 2
#
# Mode: [35, 50, 80, 40, 75]

# %% [markdown]
# Dalam Practice 1.1 Latihan 2, nilai UAS pada mata pelajaran matematika di kelas A: 95, 35, 50, 65, 70, 85, 25, 100, 80, 90, 45, 40, 35, 20, 75, 50, 40, 60, 80, 75. Menggunakan Mean, Median, dan Modus, yang paling bagus adalah Mean, karena data tersebar dengan rapi, dan tidak ada yang jauh berbeda dari yang lainnya, dimana misal itu terjadi, median akan lebih baik dari mean. Jumlah Modus (hitam) pun terlalu banyak karena banyak data yang sama dalam jumlah frekuensi.
