# %% [markdown]
# Module 1.2 Practice
#
# Nathan Kho Pancras
#
# 5027231002, Stat-Prob (B)

# %%
import matplotlib.pyplot as plt

# Function to calculate the mean
def calculate_mean(data):
    return sum(data) / len(data)

# Fungsi untuk menghitung rentang
def calculate_range(data):
    nilai_tertinggi = max(data)
    print(f"Max Value: {nilai_tertinggi}")

    nilai_terendah = min(data)
    print(f"Min Value: {nilai_terendah}")

    # Selisih antara nilai tertinggi dan terendah
    data_range = max(data) - min(data)
    
    print(f"Range: {nilai_tertinggi} - {nilai_terendah} = {data_range}")  
    
    return data_range

# Fungsi untuk menghitung rata-rata
def calculate_mean(data):
    return sum(data) / len(data)

# Fungsi untuk menghitung variansi
def calculate_variance(data):
    # Rata-rata 
    mean = calculate_mean(data)

    squared_diff = []
    for x in data:
        squared_diff_per_x = (x - mean)**2
        squared_diff.append( squared_diff_per_x )   
    
    # Jumlah kuadrat selisih antara setiap nilai data dengan rata-rata, kemudian dibagi dengan jumlah total data
    variance = sum(squared_diff) / len(data)
      
    print(f"Variance: {sum(squared_diff)} / {len(data)} = {variance}")    
    
    return variance

def calculate_std_deviation(data):
    variance = calculate_variance(data)
    standard_deviation = variance**0.5
    print(f"Standard Deviation: {variance}**0.5 = {standard_deviation}")
    
    return standard_deviation


# Inisialisasi dataset
data = [19, 10, 10, 12, 13, 15, 14, 13, 9, 17]
print(f"Data: {data}")

sorted_data = sorted(data)
print(f"Sorted: {sorted_data}")
# Jumlah total data dalam dataset 

n = len(sorted_data)
print(f"Length: {n}\n")

mean = calculate_mean(data)
print(f"Mean: {mean}")  

data_range = calculate_range(data)
standard_deviation = calculate_std_deviation(data)

# Create a histogram
plt.hist(data, bins=15, edgecolor='black', alpha=0.5, color='green')

# Define the horizontal line coordinates
y = 1.5 # The y-coordinate where the line will be drawn
x1 = 4/70*1  # The x-coordinate of the start point
x2 = 66/70*1  # The x-coordinate of the end point

# Add a horizontal line
plt.axhline(y=y, xmin=x1, xmax=x2, color='red', linestyle='dashed', linewidth=1, label=f'Range = {calculate_range(data)}')

# Add vertical line
plt.axvline(x=min(data), color='blue', linestyle='dashed', linewidth=1, label=f'Min Data: {min(data):.2f}')
plt.axvline(x=max(data), color='blue', linestyle='dashed', linewidth=1, label=f'Max Data: {max(data):.2f}')
plt.axvline(x=mean, color='black', linestyle='dashed', linewidth=1, label=f'Mean = {mean}')
plt.axvline(x=mean - standard_deviation, color='green', linestyle='dashed', linewidth=1, label=f'{mean-standard_deviation:.2f}')
plt.axvline(x=mean + standard_deviation, color='green', linestyle='dashed', linewidth=1, label=f'{mean+standard_deviation:.2f}')

# Add labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Range, Variance, Standard Deviation')

# Add legend
plt.legend()

# Show the plot
plt.show()
# Out:
# Data: [19, 10, 10, 12, 13, 15, 14, 13, 9, 17]
# Sorted: [9, 10, 10, 12, 13, 13, 14, 15, 17, 19]
# Length: 10
#
# Mean: 13.2
# Max Value: 19
# Min Value: 9
# Range: 19 - 9 = 10
# Variance: 91.6 / 10 = 9.16
# Standard Deviation: 9.16**0.5 = 3.026549190084311
# Max Value: 19
# Min Value: 9
# Range: 19 - 9 = 10

# %%
import matplotlib.pyplot as plt

# Function to calculate the mean
def calculate_mean(data):
    return sum(data) / len(data)

# Fungsi untuk menghitung rentang
def calculate_range(data):
    nilai_tertinggi = max(data)
    print(f"Max Value: {nilai_tertinggi}")

    nilai_terendah = min(data)
    print(f"Min Value: {nilai_terendah}")

    # Selisih antara nilai tertinggi dan terendah
    data_range = max(data) - min(data)
    
    print(f"Range: {nilai_tertinggi} - {nilai_terendah} = {data_range}")  
    
    return data_range

# Fungsi untuk menghitung rata-rata
def calculate_mean(data):
    return sum(data) / len(data)

# Fungsi untuk menghitung variansi
def calculate_variance(data):
    # Rata-rata 
    mean = calculate_mean(data)

    squared_diff = []
    for x in data:
        squared_diff_per_x = (x - mean)**2
        squared_diff.append( squared_diff_per_x )   
    
    # Jumlah kuadrat selisih antara setiap nilai data dengan rata-rata, kemudian dibagi dengan jumlah total data
    variance = sum(squared_diff) / len(data)
      
    print(f"Variance: {sum(squared_diff)} / {len(data)} = {variance}")    
    
    return variance

def calculate_std_deviation(data):
    variance = calculate_variance(data)
    standard_deviation = variance**0.5
    print(f"Standard Deviation: {variance}**0.5 = {standard_deviation}")
    
    return standard_deviation


# Inisialisasi dataset
data = [180, 185, 175, 190, 170, 195, 165]
print(f"Data: {data}")

sorted_data = sorted(data)
print(f"Sorted: {sorted_data}")
# Jumlah total data dalam dataset 

n = len(sorted_data)
print(f"Length: {n}\n")

mean = calculate_mean(data)
print(f"Mean: {mean}")  

data_range = calculate_range(data)
standard_deviation = calculate_std_deviation(data)

# Create a histogram
plt.hist(data, bins=15, edgecolor='black', alpha=0.5, color='green')

# Define the horizontal line coordinates
y = 1.5 # The y-coordinate where the line will be drawn
x1 = 4/70*1  # The x-coordinate of the start point
x2 = 66/70*1  # The x-coordinate of the end point

# Add a horizontal line
plt.axhline(y=y, xmin=x1, xmax=x2, color='red', linestyle='dashed', linewidth=1, label=f'Range = {calculate_range(data)}')

# Add vertical line
plt.axvline(x=min(data), color='blue', linestyle='dashed', linewidth=1, label=f'Min Data: {min(data):.2f}')
plt.axvline(x=max(data), color='blue', linestyle='dashed', linewidth=1, label=f'Max Data: {max(data):.2f}')
plt.axvline(x=mean, color='black', linestyle='dashed', linewidth=1, label=f'Mean = {mean}')
plt.axvline(x=mean - standard_deviation, color='green', linestyle='dashed', linewidth=1, label=f'{mean-standard_deviation:.2f}')
plt.axvline(x=mean + standard_deviation, color='green', linestyle='dashed', linewidth=1, label=f'{mean+standard_deviation:.2f}')

# Add labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Range, Variance, Standard Deviation')

# Add legend
plt.legend()

# Show the plot
plt.show()
# Out:
# Data: [180, 185, 175, 190, 170, 195, 165]
# Sorted: [165, 170, 175, 180, 185, 190, 195]
# Length: 7
#
# Mean: 180.0
# Max Value: 195
# Min Value: 165
# Range: 195 - 165 = 30
# Variance: 700.0 / 7 = 100.0
# Standard Deviation: 100.0**0.5 = 10.0
# Max Value: 195
# Min Value: 165
# Range: 195 - 165 = 30

# %% [markdown]
# Dalam Practice 1.1 Latihan 1 dan 2, Latihan 1 adalah data tentang jumlah gol pemain klub dan Latihan 2 adalah data tentang tinggi badan di tim olahraga.
#
# Sesuai grafik, persebaran kedua data tidak memiliki sebuah outlier (data yang jauh berbeda) yang membuat mean, range, dan standar deviasi menjadi lebih natural sesuai data.
#
# Untuk hasil Latihan 1, standar deviasi sangat natural dan sesuai data, tetapi mean sedikit tergeser ke kiri.
#
# Untuk hasil Latihan 2, mean terletak tepat di tengah histogram sehingga terbentuk persebaran yang rata dari tinggi badan tim olahraga.
